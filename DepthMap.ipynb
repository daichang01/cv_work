# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
imgL = cv.imread('l.jpg', cv.IMREAD_GRAYSCALE)
imgR = cv.imread('r.jpg', cv.IMREAD_GRAYSCALE)
 # 获取第二张图片的尺寸
# target_size = imgR.shape[1], imgR.shape[0]

# # 将第一张图片调整为目标大小
# imgL = cv.resize(imgL, target_size)

stereo = cv.StereoBM.create(numDisparities=32, blockSize=5) #视差范围大小，块大小
disparity = stereo.compute(imgL,imgR)
plt.imshow(disparity,'gray')
plt.show()
